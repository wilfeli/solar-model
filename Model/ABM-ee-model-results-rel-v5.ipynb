# %%
import ctypes
import os
import threading
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm
matplotlib.style.use('ggplot')
import math
import concurrent.futures
import glob
import json
import scipy as sp
import scipy.special
from matplotlib.ticker import FormatStrFormatter

# %%
#read setup file and change seed
test_mode = 'StrangeReliability'
data_mode = 'CA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 19:34:46  INFO: started running
# time: Wed 2017-02-15 19:35:10  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 19:35:28  INFO: started running
# time: Wed 2017-02-15 19:35:42  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 19:35:59  INFO: started running
# time: Wed 2017-02-15 19:36:07  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 19:36:24  INFO: started running
# time: Wed 2017-02-15 19:36:45  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#read setup file and change seed
test_mode = 'StrangeReliability'
data_mode = 'CA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2015,):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 12:38:10  INFO: started running
# time: Wed 2017-02-15 12:38:44  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0         12.75            12.75    3.601545  3.735980  0.164596  0.163400
# 1          9.25            22.00    3.629047  3.668052  0.185985  0.176355
# 2         11.25            33.25    3.772223  3.812510  0.192465  0.199199
# 3         10.00            43.25    3.664847  3.719985  0.203374  0.176194
# 4          8.25            51.50    3.759020  3.791390  0.205168  0.189395
# 5         11.75            63.25    3.769760  3.818463  0.197125  0.200548
Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 12:39:46  INFO: started running
# time: Wed 2017-02-15 12:40:01  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 12:40:18  INFO: started running
# time: Wed 2017-02-15 12:40:25  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 12:40:42  INFO: started running
# time: Wed 2017-02-15 12:40:52  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-02-15 12:41:09  INFO: started running
# time: Wed 2017-02-15 12:41:23  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.163817  0.161222
# 1         10.25            17.50    2.961110  3.068060  0.188617  0.164257
# 2          8.25            25.75    2.928605  2.985305  0.183855  0.172246
# 3          8.75            34.50    2.755765  2.789847  0.177539  0.195756
# 4          7.50            42.00    2.653922  2.674740  0.199609  0.195756
# 5          5.25            47.25    2.863210  2.878977  0.203101  0.205440
# 6         10.00            57.25    2.722300  2.791515  0.221884  0.235722
# 7          7.50            64.75    2.776720  2.781025  0.233181  0.267966
# 8          8.75            73.50    2.775968  2.907287  0.274749  0.267966
# 9         10.75            84.25    2.702000  2.770805  0.239946  0.251115
