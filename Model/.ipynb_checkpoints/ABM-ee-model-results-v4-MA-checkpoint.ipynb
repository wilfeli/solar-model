# %%
# sample.py
import ctypes
import os
import threading
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm
matplotlib.style.use('ggplot')
import math
import concurrent.futures
import glob
import json
import scipy as sp
import scipy.special
from matplotlib.ticker import FormatStrFormatter

# %%
#read setup file and change seed
test_mode = 'LowReliabilityPrior'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:26:19  INFO: started running
# time: Sat 2017-01-21 19:26:22  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:26:39  INFO: started running
# time: Sat 2017-01-21 19:26:41  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:26:58  INFO: started running
# time: Sat 2017-01-21 19:27:02  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:27:19  INFO: started running
# time: Sat 2017-01-21 19:27:23  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.163817  0.163400
# 1          9.25            16.50    3.089987  3.207102  0.181776  0.166603
# 2          7.75            24.25    3.033438  3.083180  0.185046  0.168378
# 3          8.50            32.75    2.773602  2.808585  0.203798  0.179492
# 4          8.50            41.25    2.697675  2.703230  0.217371  0.242082
# 5          8.75            50.00    2.618733  2.629680  0.231116  0.246876
# 6         12.75            62.75    2.658822  2.744800  0.215807  0.226368
# 7          9.50            72.25    2.649710  2.692048  0.219763  0.236841
# 8          9.25            81.50    2.523710  2.539960  0.232241  0.242515
# 9          8.75            90.25    2.623440  2.721268  0.236781  0.282940
# 10         9.25            99.50    2.643680  2.699618  0.223895  0.253526
# 11         8.75           108.25    2.484840  2.514857  0.259176  0.260700
# 12        10.00           118.25    2.517415  2.523555  0.281939  0.259292
# 13         8.75           127.00    2.525050  2.543675  0.319048  0.282934
# 14         8.00           135.00    2.524725  2.583820  0.286497  0.348878
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2
# 0   0.158250   0.117857   0.200000   0.200000
# 1   0.161428   0.166089   0.161779   0.161779
# 2   0.159751   0.256143   0.433595   0.285064
# 3   0.169459   2.034079   0.436570   0.241329
# 4   0.183410   0.530411   0.170525   0.201359
# 5   0.214552   2.172998   0.164204   4.858912
# 6   0.217472   2.163225   0.150820   1.130757
# 7   0.236788   1.945329   0.103126   2.701225
# 8   0.240747   1.941738   0.708503   2.670802
# 9   0.300297  57.168639   1.432756   0.894420
# 10  0.308240  18.535162   0.729336   0.892885
# 11  0.308240  22.719065   0.727148   0.892885
# 12  0.287945   4.268759   0.761985   9.496144
# 13  0.335687   0.395796   1.362470  17.838834
# 14  0.335687   0.220041   0.700796  17.838834

# %%
#read setup file and change seed
test_mode = 'Standard'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-01-25 07:06:56  INFO: started running
# time: Wed 2017-01-25 07:06:59  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-01-25 07:07:16  INFO: started running
# time: Wed 2017-01-25 07:07:19  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-01-25 07:07:37  INFO: started running
# time: Wed 2017-01-25 07:07:39  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Wed 2017-01-25 07:07:58  INFO: started running
# time: Wed 2017-01-25 07:08:02  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.172074  0.163400
# 1          8.25            15.50    3.264827  3.383890  0.201239  0.172951
# 2          9.25            24.75    2.826727  2.876275  0.185313  0.173449
# 3          9.50            34.25    2.701998  2.762980  0.234546  0.176569
# 4          9.50            43.75    2.593385  2.597485  0.232962  0.208095
# 6   0.231632   7.776368  212.582755   0.399833
# 7   0.231632  21.051553    0.117098   0.399833
# 8   0.242348   5.363698    0.908416   5.658471
# 9   0.258274  29.447452    2.357586   1.653104
# 10  0.254747  28.822114    1.492761   1.582190
# 11  0.277869  28.393721    1.492761  36.716703
# 12  0.314683   0.027599   23.116189  35.249834
# 13  0.314683   9.265010   16.615561  35.249834
# 14  0.287775  12.018620   16.581644  35.249924

# %%
#read setup file and change seed
test_mode = 'LowReliabilitySem'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:44:23  INFO: started running
# time: Sat 2017-01-21 19:44:27  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:44:45  INFO: started running
# time: Sat 2017-01-21 19:44:47  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:45:04  INFO: started running
# time: Sat 2017-01-21 19:45:07  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:45:24  INFO: started running
# time: Sat 2017-01-21 19:45:27  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.169685  0.163400
# 1          9.25            16.50    3.099500  3.226925  0.174194  0.168485
# 2          8.50            25.00    3.020967  3.082235  0.187448  0.179789
# 3          8.50            33.50    2.720487  2.802970  0.211050  0.200586
# 4         10.75            44.25    2.530147  2.542377  0.243003  0.210628
# 5          8.00            52.25    2.513877  2.526800  0.226184  0.215163
# 6         14.00            66.25    2.535405  2.608977  0.222893  0.209802
# 7         10.25            76.50    2.549198  2.604097  0.228933  0.216380
# 8         11.00            87.50    2.508355  2.559928  0.228141  0.223765
# 9          9.50            97.00    2.492217  2.546403  0.249242  0.250989
# 10         9.25           106.25    2.435455  2.448198  0.313822  0.234433
# 11         8.00           114.25    2.444247  2.586148  0.290778  0.314233
# 12         8.00           122.25    2.404837  2.424795  0.292496  0.317966
# 13        10.25           132.50    2.522857  2.606010  0.300699  0.355892
# 14         6.75           139.25    2.491557  2.615123  0.317776  0.333053
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2
# 0   0.158250   0.228063   0.250000   0.250000
# 1   0.168822   0.284641   0.242494   0.669456
# 2   0.174708   0.368754   0.731961   0.774678
# 3   0.210796   0.718694   0.267651   0.329178
# 4   0.202736   0.101517   0.274096   0.423375
# 5   0.203195   0.122961   0.983407   0.400318
# 6   0.237226   5.537127  11.036444   1.151878
# 7   0.237226   5.565889   2.864554   1.151878
# 8   0.242775   5.539464   0.692497   1.219695
# 9   0.262018   6.142638   1.336316   2.313372
# 10  0.291266   5.972803   0.741031   1.572821
# 11  0.291266   0.124073   0.114045   1.572821
# 12  0.291266   4.811540  11.723783   1.572821
# 13  0.326465   6.960050  15.133861   0.337526
# 14  0.333722   6.956980  13.428406   0.322416

# %%
#read setup file and change seed
test_mode = 'LowEfficiencyGrowth'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:46:52  INFO: started running
# time: Sat 2017-01-21 19:46:57  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:47:16  INFO: started running
# time: Sat 2017-01-21 19:47:19  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:47:37  INFO: started running
# time: Sat 2017-01-21 19:47:40  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:47:57  INFO: started running
# time: Sat 2017-01-21 19:48:00  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# 3   0.168088    0.216295   1.946532    0.164814
# 4   0.186481    3.691488   1.488660    1.415709
# 5   0.194131    4.082903   1.488660    1.421355
# 6   0.223562    5.495167   1.488660    1.408740
# 7   0.231319    3.879034   0.170844    3.981483
# 8   0.233995    5.451585   0.251372    3.983754
# 9   0.233995    5.434089   0.814952    3.983754
# 10  0.261105  195.099399   0.814952    0.229914
# 11  0.272269  191.416758   0.825456    0.269948
# 12  0.286347   82.198755   0.653027    0.264047
# 13  0.286347   68.329901   0.653027    0.264047
# 14  0.335805   68.329957   0.652861  136.847665

# %%
#read setup file and change seed
test_mode = 'Exploiters'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:54:19  INFO: started running
# time: Sat 2017-01-21 19:54:22  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:54:39  INFO: started running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:54:58  INFO: started running
# time: Sat 2017-01-21 19:55:00  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:55:17  INFO: started running
# time: Sat 2017-01-21 19:55:20  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.00             7.00    3.505335  3.507450  0.166900  0.162625
# 1          9.50            16.50    3.176050  3.244458  0.167603  0.169416
# 2          7.00            23.50    2.841582  2.934107  0.171161  0.168024
# 3          9.25            32.75    2.773852  2.816135  0.186972  0.177210
# 4          7.75            40.50    2.774110  2.768607  0.218630  0.219885
# 5          8.25            48.75    2.644362  2.685427  0.210821  0.223280
# 6         11.25            60.00    2.758312  2.867980  0.209363  0.229991
# 7          9.25            69.25    2.614443  2.675835  0.222280  0.229991
# 8         11.75            81.00    2.557578  2.580852  0.221670  0.213588
# 9         10.50            91.50    2.580907  2.615477  0.223540  0.226795
# 10         8.25            99.75    2.598945  2.630648  0.244767  0.244458
# 11        10.50           110.25    2.573585  2.711770  0.248941  0.280458
# 12         8.25           118.50    2.554105  2.581265  0.257543  0.256040
# 13         8.75           127.25    2.497070  2.534100  0.267982  0.256040
# 14         7.75           135.00    2.505340  2.521562  0.299530  0.303743
#
#        sei_2  sei_rel_0  sei_rel_1   sei_rel_2
# 0   0.159850   0.112746   0.200000    0.200000
# 1   0.166428   0.100116   0.107431    0.123558
# 2   0.172671   0.206253   0.455636    0.097754
# 3   0.171196   0.348265   0.452203    0.139897
# 4   0.193375   0.965903   0.512949    0.340572
# 5   0.193375   1.395788   0.515299    0.340572
# 6   0.218511   0.417628  42.517367    0.639519
# 7   0.252174   0.641784  42.517367    0.617812
# 8   0.252174   0.220171  42.472692    0.617812
# 9   0.260857   0.225098  42.662311    0.619587
# 10  0.267773  10.379188  43.004446    0.408162
# 11  0.267773  10.316255  34.731251    0.408162
# 12  0.279376  82.731667  34.558822    0.406032
# 13  0.327101  49.115417  34.558822    0.165047
# 14  0.335776  56.477349   8.868547  139.947738

# %%
#read setup file and change seed
test_mode = 'Explorers'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:55:38  INFO: started running
# time: Sat 2017-01-21 19:55:41  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:55:59  INFO: started running
# time: Sat 2017-01-21 19:56:02  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:56:21  INFO: started running
# time: Sat 2017-01-21 19:56:24  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Sat 2017-01-21 19:56:42  INFO: started running
# time: Sat 2017-01-21 19:56:45  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.168263  0.164137
# 1          9.75            17.00    3.075918  3.199777  0.177473  0.171005
# 2          8.50            25.50    2.940575  2.996875  0.198744  0.172845
# 3          7.75            33.25    2.868535  2.938075  0.210189  0.172543
# 4          8.25            41.50    2.671840  2.678740  0.203141  0.220979
# 5          7.25            48.75    2.511532  2.521643  0.208205  0.228558
# 6         13.25            62.00    2.587547  2.659162  0.237077  0.225186
# 7          9.25            71.25    2.563982  2.626380  0.244928  0.259425
# 8         11.75            83.00    2.527842  2.562890  0.253542  0.259897
# 9         12.50            95.50    2.498690  2.540838  0.265568  0.277359
# 10         9.75           105.25    2.522075  2.554123  0.332563  0.294805
# 11         8.00           113.25    2.468115  2.487312  0.286695  0.304777
# 12         7.75           121.00    2.597988  2.743337  0.298624  0.304769
# 13        10.25           131.25    2.420100  2.447217  0.356723  0.298575
# 14         8.75           140.00    2.497405  2.524900  0.357103  0.325307
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2
# 0   0.158250   0.357632   0.182219   0.200000
# 1   0.168822   0.155902   0.488123   0.535564
# 2   0.167145   0.226768   0.167567   0.658849
# 3   0.177542   0.772398   0.191585   0.708799
# 4   0.198860   0.471630   0.144848   0.584374
# 5   0.203058   0.349008   9.437676   0.169835
# 6   0.205965   1.047727   9.753866   4.486163
# 7   0.226655   1.939058   0.518377   0.433104
# 8   0.237354   0.127107   0.523709   0.431814
# 9   0.236768   1.063593   9.151342   0.384365
# 10  0.286062   0.133070   8.742357   0.401979
# 11  0.296296   1.563830   8.769813   2.275207
# 12  0.341282   0.638977   0.758253   6.204755
# 13  0.318043  17.737004   0.874059   4.979530
# 14  0.319422  32.078587  29.229501   5.017211

# %%
#read setup file and change seed
test_mode = ''
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
