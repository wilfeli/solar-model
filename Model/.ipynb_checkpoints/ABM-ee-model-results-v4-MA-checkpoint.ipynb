# %%
# sample.py
import ctypes
import os
import threading
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import cm
matplotlib.style.use('ggplot')
import math
import concurrent.futures
import glob
import json
import scipy as sp
import scipy.special
from matplotlib.ticker import FormatStrFormatter

# %%
#read setup file and change seed
test_mode = 'LowReliabilityPrior'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:35:35  INFO: started running
# time: Thu 2017-01-26 20:35:40  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:36:05  INFO: started running
# time: Thu 2017-01-26 20:36:09  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:36:27  INFO: started running
# time: Thu 2017-01-26 20:36:30  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:36:47  INFO: started running
# time: Thu 2017-01-26 20:36:50  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.166072  0.163400
# 1          9.00            16.25    3.120900  3.239685  0.166075  0.166603
# 2          7.75            24.00    3.031557  3.081290  0.166075  0.185841
# 3          8.25            32.25    2.762923  2.794517  0.188715  0.185841
# 4          7.75            40.00    2.861400  2.862527  0.221150  0.201636
# 5          7.75            47.75    2.622313  2.626055  0.212094  0.188693
# 6         11.50            59.25    2.740177  2.826675  0.222828  0.225649
# 7          9.25            68.50    2.739265  2.826390  0.224123  0.224718
# 8         11.25            79.75    2.647757  2.715900  0.247969  0.222065
# 9         11.25            91.00    2.580647  2.624932  0.273796  0.222065
# 10         9.75           100.75    2.630295  2.648907  0.260482  0.229840
# 11         7.75           108.50    2.569198  2.691350  0.289689  0.229840
# 12         8.50           117.00    2.622045  2.647390  0.295473  0.245994
# 13         9.00           126.00    2.544323  2.577002  0.320606  0.244559
# 14         6.50           132.50    2.542568  2.559475  0.341178  0.257585
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.111076   0.200000   0.200000   ...      0.096278   0.375584
# 1   0.164944   0.394866   0.161779   0.126028   ...      0.075683   0.285536
# 2   0.163266   0.394866   0.096631   0.249313   ...      0.137966   0.307993
# 3   0.163266   0.475142   0.096631   0.249313   ...      0.536189   0.231695
# 4   0.202017   0.345131   0.052140   3.142615   ...      2.484799   0.160077
# 5   0.182684   0.342660   0.234904   3.131986   ...      4.320552   0.099106
# 6   0.182684   0.345544  34.438312   3.131986   ...      8.356440   0.180517
# 7   0.209263   0.587771  34.488111   1.864284   ...      6.488206   0.096521
# 8   0.209263   1.515607  36.575683   1.864284   ...      2.497815   0.071970
# 9   0.209263   1.816004  36.575683   1.864284   ...      2.362501   0.062525
# 10  0.220997   2.224945  36.523509   1.910961   ...      7.038025   0.095487
# 11  0.228929   9.397298  36.523509   2.353516   ...      9.364359   0.099707
# 12  0.268215   2.883264   3.471301   0.580980   ...      2.213762   0.099239
# 13  0.268215   3.179310   2.449724   0.580980   ...      3.045738   0.145948
# 14  0.313609   2.952969   0.339544   0.578729   ...      1.391278   0.200955
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.351434   0.325546   0.157124   0.174009   0.351865     1.75     2.25
# 1    0.388741   0.448774   0.447753   0.101946   1.043326     7.50     4.25
# 2    0.327689   0.900488   0.593221   0.196519   2.177824    10.75     6.25
# 3    0.528233   1.886654   1.212859   0.102933   1.763332    13.25     9.75
# 4    0.286848   3.092095   0.850860   0.240797   2.477782    16.75    12.75
# 5    0.207689   9.438187   1.096634   0.437714   2.214147    19.50    15.75
# 6    0.718030  34.246218   2.057028   1.568094   4.832478    23.25    21.50
# 7    0.751112  26.695083   1.940995   2.141683   2.774995    26.50    24.25
# 8    0.995376  42.381926   1.620786   1.687301   3.522642    30.25    27.25
# 9    0.537140  55.459670   1.833960   1.033861   8.451516    33.75    31.75
# 10   1.575825  19.243628   4.219212   1.356835   3.056375    36.75    34.50
# 11   4.252149  35.469399   9.432313   1.993502   5.159740    38.75    38.50
# 12   2.782134  10.806331  12.663444   5.463100   5.450583    42.00    41.75
# 13  18.227311   4.215095  22.428023   4.237124   3.832363    45.50    44.75
# 14  25.894487   4.536663  12.297033  38.157294   8.148447    47.00    47.25
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      7.00
# 3      9.25
# 4     10.50
# 5     12.50
# 6     14.50
# 7     17.75
# 8     22.25
# 9     25.50
# 10    29.50
# 11    31.25
# 12    33.25
# 13    35.75
# 14    38.25
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'Standard'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:45:10  INFO: started running
# time: Thu 2017-01-26 20:45:14  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:45:31  INFO: started running
# time: Thu 2017-01-26 20:45:33  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:45:50  INFO: started running
# time: Thu 2017-01-26 20:45:52  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:46:09  INFO: started running
# time: Thu 2017-01-26 20:46:12  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))



#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    

    #create new column with max and min
    df_['sem_max'] = df_[['sem_' + str(i) for i in range(7)]].max(axis=1)
    df_['sem_rel_min'] = df_[['sem_rel_' + str(i) for i in range(7)]].min(axis=1)
    df_['sei_max'] = df_[['sei_' + str(i) for i in range(3)]].min(axis=1)
    df_['sei_rel_min'] = df_[['sei_rel_' + str(i) for i in range(3)]].min(axis=1)
    
    dfs_.append(df_)
    
    
#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.163817  0.163400
# 1          9.00            16.25    3.115622  3.235482  0.162589  0.166603
# 2          8.00            24.25    3.003260  3.053027  0.187184  0.183497
# 3          8.25            32.50    2.836587  2.862495  0.201028  0.195955
# 4          8.00            40.50    2.634785  2.645563  0.202840  0.198002
# 5          7.25            47.75    2.702085  2.712550  0.200735  0.187200
# 6         12.00            59.75    2.671455  2.759117  0.237429  0.187200
# 7          9.00            68.75    2.660370  2.722775  0.245409  0.246117
# 8         11.25            80.00    2.602243  2.652170  0.252501  0.215458
# 9         10.75            90.75    2.550277  2.581385  0.285409  0.234675
# 10        10.00           100.75    2.689120  2.756545  0.260986  0.233449
# 11         8.00           108.75    2.494500  2.502738  0.262356  0.233449
# 12         6.50           115.25    2.624440  2.648930  0.289361  0.266589
# 13         7.75           123.00    2.618603  2.666185  0.359374  0.266589
# 14         8.25           131.25    2.594330  2.615953  0.353510  0.319204
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2     ...       sem_rel_4  \
# 0   0.158250   0.117857   0.200000   0.200000     ...        0.157124
# 1   0.164944   0.121013   0.161779   0.126028     ...        0.447753
# 2   0.163266   1.176684   0.089685   0.249313     ...        0.593221
# 3   0.163266   1.132350   0.917504   0.249313     ...        1.212859
# 4   0.179972   0.168079   1.002981   0.189312     ...        0.850860
# 5   0.204419   0.181040   0.018515   0.450315     ...        1.096634
# 6   0.220329   2.536960   0.018515   0.755822     ...        2.057028
# 7   0.214931   2.018780   0.042227   0.715693     ...        1.940995
# 8   0.239661   2.028276   0.014420   1.339129     ...        1.620786
# 9   0.265020   2.288181   0.963033   1.171785     ...        1.833960
# 10  0.253184   4.156588   0.049025   0.474841     ...        4.219212
# 11  0.269151   1.705113   0.049025   0.071780     ...        9.432313
# 12  0.269151   5.939764   0.518110   0.071780     ...       12.663444
# 13  0.318861  22.369684   0.518110   0.282259     ...       22.428023
# 14  0.326188   1.697671   4.670961   0.321141     ...       12.297033
#
#     sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  sei_N_2   sem_max  sem_rel_min  \
# 0    0.174009   0.351865     1.75     2.25     3.25  0.222589     0.063085
# 1    0.101946   1.043326     7.50     4.25     4.50  0.231184     0.038086
# 2    0.196519   2.177824    11.00     6.25     7.00  0.240630     0.036788
# 3    0.102933   1.763332    13.50     9.75     9.25  0.250445     0.023587
# 4    0.240797   2.477782    17.00    13.00    10.50  0.270112     0.010330
# 5    0.437714   2.214147    20.00    15.50    12.25  0.284186     0.007190
# 6    1.568094   4.832478    24.25    21.00    14.50  0.292231     0.009218
# 7    2.141683   2.774995    27.25    23.50    18.00  0.307041     0.011447
# 8    1.687301   3.522642    30.75    26.25    23.00  0.323331     0.010033
# 9    1.033861   8.451516    33.50    30.75    26.50  0.336056     0.013664
# 10   1.356835   3.056375    36.75    33.75    30.25  0.358728     0.023801
# 11   1.993502   5.159740    38.25    38.75    31.75  0.371549     0.004738
# 12   5.463100   5.450583    40.25    41.75    33.25  0.399156     0.010071
# 13   4.237124   3.832363    42.75    44.25    36.00  0.408019     0.017000
# 14  38.157294   8.148447    45.50    47.50    38.25  0.421728     0.021561
#
#      sei_max  sei_rel_min
# 0   0.158225     0.106894
# 1   0.159732     0.053330
# 2   0.160423     0.086734
# 3   0.160423     0.049369
# 4   0.169427     0.041677
# 5   0.177225     0.010822
# 6   0.187200     0.009050
# 7   0.210811     0.042227
# 8   0.202904     0.014420
# 9   0.205234     0.414206
# 10  0.209812     0.038642
# 11  0.212849     0.005203
# 12  0.224582     0.068534
# 13  0.266589     0.253324
# 14  0.285114     0.231859
#
# [15 rows x 31 columns]

# %%
plt.plot(df_means[['sem_rel_min', 'sei_rel_0', 'sei_rel_1', 'sei_rel_2']][0:15])
# Out:
# [<matplotlib.lines.Line2D at 0x108d195c0>,
#  <matplotlib.lines.Line2D at 0x108d19978>,
#  <matplotlib.lines.Line2D at 0x108d19c50>,
#  <matplotlib.lines.Line2D at 0x108d19eb8>]

# %%
plt.plot(df_means[['sem_max', 'sei_0', 'sei_1', 'sei_2']][0:15])
# Out:
# [<matplotlib.lines.Line2D at 0x1085afcf8>,
#  <matplotlib.lines.Line2D at 0x1085af4e0>,
#  <matplotlib.lines.Line2D at 0x1085af710>,
#  <matplotlib.lines.Line2D at 0x1085af8d0>]

# %%
#read setup file and change seed
test_mode = 'HighReliabilitySem'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:55:27  INFO: started running
# time: Thu 2017-01-26 20:55:30  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:55:46  INFO: started running
# time: Thu 2017-01-26 20:55:49  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:56:07  INFO: started running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 20:56:24  INFO: started running
# time: Thu 2017-01-26 20:56:27  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          6.75             6.75    3.500000  3.500000  0.168072  0.162625
# 1          9.50            16.25    3.100242  3.198345  0.176386  0.170913
# 2          6.75            23.00    2.807857  2.892855  0.176386  0.174688
# 3          8.25            31.25    2.779720  2.846715  0.198378  0.174688
# 4          8.75            40.00    2.721910  2.726445  0.210163  0.227709
# 5          7.50            47.50    2.620775  2.657088  0.185508  0.216172
# 6          9.75            57.25    2.815317  2.913603  0.220417  0.214539
# 7          9.25            66.50    2.663845  2.751578  0.238707  0.249757
# 8         10.25            76.75    2.565600  2.574852  0.298566  0.219098
# 9         10.25            87.00    2.605857  2.657350  0.292094  0.219098
# 10         7.75            94.75    2.651055  2.694183  0.241307  0.223676
# 11         7.75           102.50    2.568455  2.605767  0.235028  0.240811
# 12         8.50           111.00    2.523810  2.533743  0.277719  0.240811
# 13         8.00           119.00    2.657875  2.732137  0.277719  0.232674
# 14         8.00           127.00    2.639435  2.776292  0.292177  0.239379
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.160325   0.098346   0.125000   0.125000   ...      0.066618   0.305090
# 1   0.174075   0.924319   0.082715   0.524419   ...      0.079249   0.259535
# 2   0.172398   0.924319   0.053110   0.647704   ...      0.201740   0.355372
# 3   0.183527   0.491668   0.053110   2.895404   ...      1.161416   0.241580
# 4   0.183527   0.119178   0.387320   2.895404   ...      8.045219   0.140741
# 5   0.189831   0.033407   0.361866   0.489122   ...     16.405651   0.085931
# 6   0.233812   0.623544   0.118494   1.311145   ...     38.531907   0.181234
# 7   0.243887   0.612140   0.152330  21.452776   ...     27.472046   0.075680
# 8   0.265765   0.387906   0.124523  22.134201   ...      7.745771   0.049139
# 9   0.299734   5.187376   0.124523   6.007204   ...      7.409203   0.043119
# 10  0.301427  26.304936   0.135363   1.090942   ...     30.759203   0.062644
# 11  0.301427  35.093182   2.984651   1.090942   ...     44.393758   0.068245
# 12  0.301427   5.050211   2.984651   1.090942   ...      6.844214   0.075688
# 13  0.299399   5.050211   0.043377   0.105326   ...     10.372668   0.142660
# 14  0.299399   4.261440   1.365125   0.105326   ...      3.755380   0.186114
#
#      sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0     0.291393   0.063236   0.052128   0.143102   0.350632     1.50     2.75
# 1     0.348920   0.060614   0.238433   0.068939   1.317247     7.50     5.00
# 2     0.286688   0.033285   0.248221   0.247637   3.899077     9.75     6.75
# 3     0.568721   0.055071   0.621902   0.087792   3.829392    12.50     8.75
# 4     0.246145   0.107525   0.613023   0.041732   7.194171    16.75    11.50
# 5     0.152323   0.176415   0.700935   0.016012   5.857790    19.50    14.25
# 6     0.988151   0.241236   0.691926   0.032693  16.858176    23.75    17.25
# 7     1.040335   0.222117   0.633501   0.174540   6.391926    25.75    21.25
# 8     1.547810   0.275438   1.407284   0.079611  10.273772    30.00    22.75
# 9     0.661699   0.299922   1.508515   0.062913  35.609438    33.25    27.00
# 10    2.953082   1.722024   1.075702   0.104957   8.884607    35.75    29.50
# 11   11.793904   2.111294   4.703759   0.063854  17.148174    38.25    33.25
# 12    6.552056   1.420526   9.949656   0.029300  16.174470    39.25    36.50
# 13   88.713656   1.423156  17.751323   0.028948   9.109862    41.75    39.00
# 14  143.579213   4.269024  13.442840   0.027425  21.144461    45.00    42.00
#
#     sei_N_2
# 0      2.50
# 1      3.75
# 2      6.50
# 3     10.00
# 4     11.75
# 5     13.75
# 6     16.25
# 7     19.50
# 8     24.00
# 9     26.75
# 10    29.50
# 11    31.00
# 12    35.25
# 13    38.25
# 14    40.00
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'LowReliabilitySem'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:02:56  INFO: started running
# time: Thu 2017-01-26 21:02:59  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:03:15  INFO: started running
# time: Thu 2017-01-26 21:03:18  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:03:35  INFO: started running
# time: Thu 2017-01-26 21:03:38  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:03:54  INFO: started running
# time: Thu 2017-01-26 21:03:58  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.171411  0.163400
# 1          9.25            16.50    3.122382  3.243147  0.169542  0.168485
# 2          8.00            24.50    2.941002  2.991970  0.195775  0.194909
# 3          7.25            31.75    2.912247  2.984675  0.188489  0.207901
# 4          9.00            40.75    2.642395  2.651523  0.196376  0.207901
# 5          6.50            47.25    2.761462  2.770530  0.223944  0.197680
# 6         12.25            59.50    2.806845  2.901922  0.249875  0.197680
# 7          7.50            67.00    2.650980  2.660420  0.237515  0.217371
# 8          8.25            75.25    2.616593  2.636633  0.258560  0.229847
# 9          9.25            84.50    2.637293  2.722195  0.251070  0.229847
# 10         7.25            91.75    2.675948  2.696715  0.251070  0.224383
# 11         7.75            99.50    2.542285  2.574740  0.262875  0.230300
# 12         8.50           108.00    2.603385  2.631765  0.266559  0.230300
# 13         8.75           116.75    2.661610  2.803675  0.271394  0.286448
# 14         8.50           125.25    2.652895  2.735100  0.381190  0.286448
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.163977   0.250000   0.250000   ...      0.120347   0.469480
# 1   0.172379   0.560904   0.242494   0.150029   ...      0.094604   0.356920
# 2   0.172379   1.425259   0.302073   0.150029   ...      0.172457   0.384991
# 3   0.172379   0.223300   3.286637   0.150029   ...      0.670237   0.289619
# 4   0.219788   3.017197   3.286637   0.212564   ...      3.105992   0.200096
# 5   0.221723   0.997778   2.726940   0.166433   ...      5.400690   0.123882
# 6   0.216581   0.110558   2.726940  10.493558   ...     10.445563   0.225646
# 7   0.238785   3.491706   1.625936  11.359761   ...      8.110276   0.120652
# 8   0.240981   4.357536   3.118930  64.039564   ...      3.122278   0.089962
# 9   0.267290   1.425561   3.118930  53.651607   ...      2.953126   0.078156
# 10  0.267290   1.425561   3.056820  53.651607   ...      8.797512   0.119358
# 11  0.238090   3.187567   0.065378  53.649050   ...     11.705454   0.124633
# 12  0.232608   3.195027   0.065378  52.769687   ...      2.767208   0.124049
# 13  0.232608   0.769054   1.395998  52.769687   ...      3.807186   0.182435
# 14  0.259796   0.172717   1.395998  54.604337   ...      1.739098   0.251193
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.439293   0.406931   0.196404   0.217511   0.439831     1.75     2.25
# 1    0.485927   0.560967   0.559691   0.127432   1.304158     7.75     4.25
# 2    0.409612   1.125608   0.741526   0.245649   2.722282    10.75     6.75
# 3    0.660291   2.358319   1.516074   0.128667   2.204163    13.25     9.00
# 4    0.358562   3.865112   1.063577   0.300997   3.097230    17.00    13.75
# 5    0.259611  11.797752   1.370790   0.547142   2.767686    18.25    16.75
# 6    0.897535  42.807960   2.571284   1.960117   6.040587    21.75    21.75
# 7    0.938891  33.368792   2.426245   2.677102   3.468744    23.50    24.75
# 8    1.244221  52.977596   2.025982   2.109127   4.403296    25.25    27.50
# 9    0.671425  69.324650   2.292450   1.292327  10.564393    28.00    31.50
# 10   1.969779  24.054541   5.274032   1.696042   3.820442    29.25    33.50
# 11   5.315193  44.336811  11.790385   2.491879   6.449679    31.50    36.50
# 12   3.477692  13.507914  15.829310   6.828893   6.813210    34.50    39.25
# 13  22.784145   5.268882  28.035036   5.296405   4.790442    37.25    42.75
# 14  32.368232   5.670841  15.371318  47.696618  10.185565    39.75    45.50
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      7.00
# 3      9.50
# 4     10.00
# 5     12.25
# 6     16.00
# 7     18.75
# 8     22.50
# 9     25.00
# 10    29.00
# 11    31.50
# 12    34.25
# 13    36.75
# 14    40.00
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'LowEfficiencyGrowth'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:04:15  INFO: started running
# time: Thu 2017-01-26 21:04:18  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:04:34  INFO: started running
# time: Thu 2017-01-26 21:04:38  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:04:55  INFO: started running
# time: Thu 2017-01-26 21:04:57  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:05:15  INFO: started running
# time: Thu 2017-01-26 21:05:18  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.169658  0.163400
# 1          8.25            15.50    3.257487  3.375210  0.188406  0.169258
# 2          8.75            24.25    2.954423  3.022030  0.187509  0.181053
# 3          8.75            33.00    2.774470  2.824355  0.189985  0.204267
# 4         10.00            43.00    2.641507  2.649612  0.191416  0.221612
# 5          9.00            52.00    2.718303  2.802688  0.210784  0.203570
# 6         12.00            64.00    2.755535  2.842822  0.229217  0.210601
# 7          9.50            73.50    2.723367  2.778948  0.228379  0.220416
# 8          8.75            82.25    2.637480  2.706167  0.245237  0.226492
# 9          9.75            92.00    2.614777  2.651390  0.262699  0.284316
# 10        10.50           102.50    2.551448  2.616738  0.262699  0.278999
# 11         8.25           110.75    2.469927  2.481747  0.257920  0.279446
# 12         9.00           119.75    2.558108  2.621020  0.301418  0.279446
# 13         9.50           129.25    2.535732  2.573980  0.293763  0.275325
# 14         8.75           138.00    2.537028  2.564985  0.340447  0.323042
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.200223   0.200000   0.200000   ...      0.111125   0.281377
# 1   0.170161   0.417816   0.231912   0.647981   ...      0.068335   0.183400
# 2   0.174518   0.197097   0.194149   0.614110   ...      0.104672   0.185872
# 3   0.177140   0.589105   2.232767   0.539186   ...      0.083381   0.188194
# 4   0.199447   0.126247   0.350242   0.503972   ...      0.063175   0.222603
# 5   0.225448   0.124322   6.934453   0.606193   ...      0.113151   0.129906
# 6   0.219058   0.331111   6.859057   0.697760   ...      0.351448   0.295917
# 7   0.225293   0.254244   6.844923   0.753779   ...      0.323879   0.300300
# 8   0.242247   1.220752   7.021069   0.419991   ...      0.600042   0.304357
# 9   0.251642   0.761835   0.417309   0.585616   ...      0.762407   0.394213
# 10  0.273889   0.761835   0.461756   0.910486   ...      1.274182   0.587211
# 11  0.283462   0.692433   0.351539   0.727218   ...      1.636697   0.969253
# 12  0.274010  23.697417   0.351539   0.197116   ...      2.215850   1.274053
# 13  0.303906  23.906846   0.542821   0.231596   ...      2.146153   2.116107
# 14  0.303906   6.724686   5.597490   0.231596   ...      5.327418   2.010889
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.430855   0.123798   0.150176   0.164313   0.275027     1.75     2.25
# 1    0.445690   0.274501   0.332532   0.198328   0.852698     6.75     4.25
# 2    0.367439   0.188135   0.251034   0.470162   1.456012    10.00     7.00
# 3    0.849025   0.227878   0.430014   2.008593   0.649334    12.25    10.00
# 4    1.336245   0.110348   0.241537   3.480526   0.832123    16.25    14.75
# 5    1.972809   0.286571   0.339650   6.716912   1.595354    19.50    18.25
# 6    6.906802   0.191151   1.327690   5.205245   1.099812    23.75    22.00
# 7    8.982885   0.171219   1.285341   4.010975   1.186452    26.25    25.50
# 8    7.690709   0.879576   0.684974   3.707045   0.688381    29.75    28.50
# 9    4.841912   0.446306   0.636745   3.935619   0.699488    31.75    32.75
# 10   5.863480   0.248799   0.894212   4.321210   0.789181    34.50    35.75
# 11   8.618946   0.250519   0.785667   5.815451   0.712938    36.00    40.25
# 12  23.856716   0.338891   1.240646  11.706647   4.627317    38.25    43.75
# 13  18.573096   0.288919   2.042347   9.773582   3.695742    41.50    46.25
# 14  44.961241   0.291426   2.066100   6.219913   5.439092    43.25    50.00
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      7.25
# 3     10.75
# 4     12.00
# 5     14.25
# 6     18.25
# 7     21.75
# 8     24.00
# 9     27.50
# 10    32.25
# 11    34.50
# 12    37.75
# 13    41.50
# 14    44.75
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'HighEfficiencyGrowth'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:05:35  INFO: started running
# time: Thu 2017-01-26 21:05:38  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:05:58  INFO: started running
# time: Thu 2017-01-26 21:06:01  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:06:22  INFO: started running
# time: Thu 2017-01-26 21:06:26  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:06:43  INFO: started running
# time: Thu 2017-01-26 21:06:46  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.166312  0.163400
# 1          8.00            15.25    3.293730  3.406923  0.169772  0.171470
# 2          8.25            23.50    2.927843  2.966220  0.176462  0.175774
# 3          9.25            32.75    2.734508  2.769125  0.187326  0.175774
# 4          6.50            39.25    2.767155  2.798900  0.194048  0.191925
# 5          9.75            49.00    2.724872  2.839613  0.216522  0.241125
# 6         13.00            62.00    2.659675  2.697607  0.220044  0.220124
# 7          8.25            70.25    2.657638  2.724775  0.227471  0.257367
# 8         10.25            80.50    2.600998  2.653605  0.270951  0.257367
# 9         11.50            92.00    2.632088  2.684560  0.291633  0.276592
# 10         8.25           100.25    2.512072  2.514197  0.277050  0.255962
# 11         8.00           108.25    2.500457  2.523105  0.280477  0.268394
# 12         8.75           117.00    2.530670  2.613653  0.276039  0.268394
# 13         8.50           125.50    2.489307  2.494658  0.290317  0.357507
# 14         6.50           132.00    2.622352  2.725757  0.295007  0.331082
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...      sem_rel_0  sem_rel_1  \
# 0   0.158250   0.213749   0.200000   0.200000   ...       0.096278   0.375584
# 1   0.161872   0.481402   0.423220   0.161779   ...       0.084655   0.328283
# 2   0.160393   0.420808   0.425657   0.285064   ...       0.166951   0.430620
# 3   0.181397   0.430405   0.425657   0.850306   ...       0.602464   0.281978
# 4   0.224869   0.975454   0.436688   0.929166   ...       0.615851   0.676639
# 5   0.248326   0.081262   0.168511   0.089502   ...       0.997770   1.156871
# 6   0.253388   0.093569   0.202725   0.106688   ...       0.865369   1.422386
# 7   0.242679   0.067806   1.283215   0.518669   ...       2.018924   1.130892
# 8   0.274074   0.390973   1.283215   7.893955   ...       2.695092   1.198368
# 9   0.271086   0.595744   0.889742   0.498201   ...       3.742611   1.143311
# 10  0.274660   1.121539   1.392843   0.497653   ...      30.939079   1.093788
# 11  0.274660   0.911078   1.569315   0.497653   ...      44.581525   0.434081
# 12  0.274660   0.272442   1.569315   0.497653   ...      81.716046   0.254570
# 13  0.263922   0.297113   0.395597   0.651370   ...     219.322129   0.385850
# 14  0.263922   0.927603   0.534544   0.651370   ...     390.520813   0.271536
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.310833   0.419635   0.157124   0.174009   0.316386     1.75     2.25
# 1    0.261460   0.894865   0.457073   0.102477   0.960309     6.50     4.25
# 2    0.557503   2.368245   0.547945   0.317578   2.019360     9.50     6.75
# 3    0.429428   4.548704   1.201625   0.152494   1.018013    11.25    11.50
# 4    0.431500   4.501182   1.158868   0.177982   0.499865    14.25    13.75
# 5    0.321385   9.941986   1.757344   0.177609   0.329175    18.50    17.00
# 6    0.561232  34.885677   3.066694   0.470944   0.427136    21.75    22.00
# 7    0.440364  20.136663   1.943035   0.457191   0.448904    24.00    25.50
# 8    0.373778   6.869237   1.905599   0.357603   0.387949    27.00    29.75
# 9    0.421481   2.519173   5.763174   1.146133   0.389550    29.50    34.75
# 10   0.576229   1.805258  13.495668   1.049568   0.844975    32.25    37.25
# 11   0.384810   0.814423  11.645268   1.517354   0.196135    33.75    40.50
# 12   0.198189   0.372753   6.819783   1.426880   0.169575    37.25    43.50
# 13   0.112300   0.399643  49.833952   1.167257   0.251391    39.25    46.75
# 14   0.085813   0.507671  63.459222   1.078643   0.230214    40.75    49.50
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      7.25
# 3     10.00
# 4     11.25
# 5     13.50
# 6     18.25
# 7     20.75
# 8     23.75
# 9     27.75
# 10    30.75
# 11    34.00
# 12    36.25
# 13    39.50
# 14    41.75
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'Exploiters'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:12:41  INFO: started running
# time: Thu 2017-01-26 21:12:45  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:13:01  INFO: started running
# time: Thu 2017-01-26 21:13:04  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:13:21  INFO: started running
# time: Thu 2017-01-26 21:13:23  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:13:39  INFO: started running
# time: Thu 2017-01-26 21:13:43  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.162242  0.163400
# 1          8.25            15.50    3.212475  3.337735  0.172343  0.168107
# 2          7.75            23.25    2.985663  3.034345  0.171893  0.166567
# 3          8.75            32.00    2.824502  2.862252  0.174737  0.168743
# 4          7.00            39.00    2.752393  2.748600  0.178753  0.205102
# 5          9.75            48.75    2.722395  2.772200  0.188870  0.205102
# 6         12.75            61.50    2.687890  2.748165  0.189003  0.226240
# 7          9.50            71.00    2.646865  2.727370  0.233915  0.226809
# 8          9.75            80.75    2.563343  2.579228  0.246845  0.226809
# 9         12.75            93.50    2.616218  2.656480  0.246845  0.239651
# 10         9.50           103.00    2.620650  2.644548  0.241167  0.239651
# 11         9.00           112.00    2.503115  2.512710  0.268932  0.262064
# 12         7.50           119.50    2.605307  2.616465  0.268932  0.262064
# 13         6.50           126.00    2.579897  2.603398  0.256428  0.312551
# 14         9.00           135.00    2.576815  2.610732  0.265912  0.312551
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.106894   0.200000   0.200000   ...      0.096278   0.375584
# 1   0.161428   0.161776   0.162905   0.161779   ...      0.075683   0.285536
# 2   0.159751   0.181801   0.123611   0.285064   ...      0.137966   0.307993
# 3   0.169266   0.169270   0.116971   0.110461   ...      0.536189   0.231695
# 4   0.200965   0.037598   0.326367   0.124263   ...      2.484799   0.160077
# 5   0.205505   0.064253   0.326367   9.506932   ...      4.320552   0.099106
# 6   0.209038   0.077287   0.320500   1.702872   ...      8.356440   0.180517
# 7   0.249609   1.740683   2.206928   1.733503   ...      6.488206   0.096521
# 8   0.260533   0.261838   2.206928   1.758572   ...      2.497815   0.071970
# 9   0.260533   0.261838   2.204345   1.758572   ...      2.362501   0.062525
# 10  0.271470  18.679072   2.204345   1.769091   ...      7.038025   0.095487
# 11  0.271470  20.233340   6.183045   1.769091   ...      9.364359   0.099707
# 12  0.280068  20.233340   6.183045   1.820119   ...      2.213762   0.099239
# 13  0.292036  19.094912  10.488863   1.716821   ...      3.045738   0.145948
# 14  0.291367  19.093855  10.488863   3.045717   ...      1.391278   0.200955
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.351434   0.325546   0.157124   0.174009   0.351865     1.75     2.25
# 1    0.388741   0.448774   0.447753   0.101946   1.043326     6.75     4.25
# 2    0.327689   0.900488   0.593221   0.196519   2.177824    10.00     6.25
# 3    0.528233   1.886654   1.212859   0.102933   1.763332    12.50    10.25
# 4    0.286848   3.092095   0.850860   0.240797   2.477782    16.50    13.00
# 5    0.207689   9.438187   1.096634   0.437714   2.214147    21.00    16.50
# 6    0.718030  34.246218   2.057028   1.568094   4.832478    24.50    21.50
# 7    0.751112  26.695083   1.940995   2.141683   2.774995    28.50    24.50
# 8    0.995376  42.381926   1.620786   1.687301   3.522642    32.25    27.25
# 9    0.537140  55.459670   1.833960   1.033861   8.451516    35.75    32.75
# 10   1.575825  19.243628   4.219212   1.356835   3.056375    38.50    37.00
# 11   4.252149  35.469399   9.432313   1.993502   5.159740    39.50    41.75
# 12   2.782134  10.806331  12.663444   5.463100   5.450583    42.00    44.50
# 13  18.227311   4.215095  22.428023   4.237124   3.832363    44.00    46.50
# 14  25.894487   4.536663  12.297033  38.157294   8.148447    47.50    50.25
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      7.00
# 3      9.25
# 4      9.50
# 5     11.25
# 6     15.50
# 7     18.00
# 8     21.25
# 9     25.00
# 10    27.50
# 11    30.75
# 12    33.00
# 13    35.50
# 14    37.25
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'Explorers'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:14:00  INFO: started running
# time: Thu 2017-01-26 21:14:04  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:14:21  INFO: started running
# time: Thu 2017-01-26 21:14:24  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:14:41  INFO: started running
# time: Thu 2017-01-26 21:14:44  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:15:01  INFO: started running
# time: Thu 2017-01-26 21:15:04  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.164650  0.164137
# 1          9.75            17.00    3.070625  3.184327  0.185754  0.165714
# 2          8.75            25.75    3.005380  3.049115  0.186439  0.167968
# 3          8.00            33.75    2.817138  2.880530  0.183970  0.205134
# 4          8.25            42.00    2.695370  2.712452  0.211131  0.222855
# 5          7.00            49.00    2.735425  2.777250  0.206901  0.233036
# 6         12.75            61.75    2.668200  2.733925  0.219477  0.233797
# 7          8.00            69.75    2.650037  2.749880  0.237260  0.228792
# 8          9.75            79.50    2.614960  2.711565  0.265784  0.227679
# 9         11.25            90.75    2.555975  2.585630  0.225153  0.254179
# 10         9.00            99.75    2.641545  2.671882  0.295068  0.255792
# 11         7.75           107.50    2.621373  2.854505  0.307798  0.268884
# 12         6.50           114.00    2.598055  2.690747  0.339975  0.268884
# 13         8.25           122.25    2.637920  2.785778  0.320118  0.308307
# 14         9.25           131.50    2.576345  2.610690  0.319191  0.354433
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.286258   0.182219   0.200000   ...      0.096278   0.375584
# 1   0.168822   0.669878   0.476971   0.535564   ...      0.075683   0.285536
# 2   0.173688   0.191457   0.987147   0.145376   ...      0.137966   0.307993
# 3   0.174084   0.561504   0.992164   0.194962   ...      0.536189   0.231695
# 4   0.178042   0.217703   0.228800   0.182311   ...      2.484799   0.160077
# 5   0.184426  13.638419   0.604254   0.082070   ...      4.320552   0.099106
# 6   0.184426   0.267920   0.626012   0.082070   ...      8.356440   0.180517
# 7   0.213418   8.019685   0.566196   1.868645   ...      6.488206   0.096521
# 8   0.233848   0.123959   0.260387   1.820553   ...      2.497815   0.071970
# 9   0.237631   0.147186   0.783056   0.102050   ...      2.362501   0.062525
# 10  0.237631   4.149205  19.032858   0.102050   ...      7.038025   0.095487
# 11  0.244215   4.647191   1.055591   0.056422   ...      9.364359   0.099707
# 12  0.238662   0.522243   1.055591   0.057519   ...      2.213762   0.099239
# 13  0.242787  21.161337   5.581666   0.033883   ...      3.045738   0.145948
# 14  0.242787  28.682491  33.084258   0.033883   ...      1.391278   0.200955
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.351434   0.325546   0.157124   0.174009   0.351865     1.75     2.25
# 1    0.388741   0.448774   0.447753   0.101946   1.043326     7.50     5.00
# 2    0.327689   0.900488   0.593221   0.196519   2.177824    10.75     7.25
# 3    0.528233   1.886654   1.212859   0.102933   1.763332    13.00    10.25
# 4    0.286848   3.092095   0.850860   0.240797   2.477782    15.50    14.75
# 5    0.207689   9.438187   1.096634   0.437714   2.214147    18.25    16.75
# 6    0.718030  34.246218   2.057028   1.568094   4.832478    22.25    21.00
# 7    0.751112  26.695083   1.940995   2.141683   2.774995    24.50    24.00
# 8    0.995376  42.381926   1.620786   1.687301   3.522642    26.50    28.00
# 9    0.537140  55.459670   1.833960   1.033861   8.451516    31.00    32.00
# 10   1.575825  19.243628   4.219212   1.356835   3.056375    34.50    33.50
# 11   4.252149  35.469399   9.432313   1.993502   5.159740    36.50    36.75
# 12   2.782134  10.806331  12.663444   5.463100   5.450583    39.25    39.75
# 13  18.227311   4.215095  22.428023   4.237124   3.832363    41.75    42.75
# 14  25.894487   4.536663  12.297033  38.157294   8.148447    44.50    45.25
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      7.75
# 3     10.50
# 4     11.75
# 5     14.00
# 6     18.50
# 7     21.25
# 8     25.00
# 9     27.75
# 10    31.75
# 11    34.25
# 12    35.00
# 13    37.75
# 14    41.75
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'HighHardCosts'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:15:21  INFO: started running
# time: Thu 2017-01-26 21:15:26  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:15:43  INFO: started running
# time: Thu 2017-01-26 21:15:46  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:16:03  INFO: started running
# time: Thu 2017-01-26 21:16:08  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:16:25  INFO: started running
# time: Thu 2017-01-26 21:16:33  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.166585  0.163400
# 1          9.25            16.50    3.143937  3.262118  0.170664  0.166603
# 2          7.50            24.00    3.139885  3.195285  0.177607  0.184138
# 3          6.75            30.75    2.960985  2.990825  0.181562  0.180518
# 4          5.75            36.50    2.976637  2.988507  0.181562  0.200049
# 5          8.25            44.75    2.984522  3.001670  0.210928  0.197994
# 6          8.25            53.00    3.115725  3.208360  0.222627  0.197994
# 7          6.25            59.25    3.261177  3.368908  0.227419  0.201309
# 8          8.50            67.75    3.082440  3.155518  0.228298  0.201309
# 9          8.25            76.00    3.122787  3.160535  0.222597  0.209286
# 10         6.00            82.00    3.262848  3.278115  0.265597  0.209286
# 11         3.75            85.75    3.061993  3.067638  0.321865  0.227972
# 12         5.25            91.00    3.044080  3.061472  0.298936  0.227972
# 13         5.50            96.50    3.110717  3.151480  0.273204  0.230140
# 14         4.00           100.50    3.255020  3.261903  0.273204  0.230140
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.157145   0.200000   0.200000   ...      0.096278   0.375584
# 1   0.172338   0.230595   0.161779   0.499813   ...      0.075683   0.285536
# 2   0.172338   0.222643   0.576938   0.499813   ...      0.137966   0.307993
# 3   0.176758   0.231524   0.548895   0.638709   ...      0.536189   0.231695
# 4   0.176758   0.231524   0.797327   0.638709   ...      2.484799   0.160077
# 5   0.176758   0.028026   0.736216   0.638709   ...      4.320552   0.099106
# 6   0.185742   0.751184   0.736216   0.614653   ...      8.356440   0.180517
# 7   0.185742   0.346382   0.339123   0.614653   ...      6.488206   0.096521
# 8   0.220813  42.461528   0.339123   0.465871   ...      2.497815   0.071970
# 9   0.220813  42.305702   0.334217   0.465871   ...      2.362501   0.062525
# 10  0.258067  42.419485   0.334217   4.292102   ...      7.038025   0.095487
# 11  0.278059  12.063975   9.332298   2.346218   ...      9.364359   0.099707
# 12  0.278059   9.673700   9.332298   2.346218   ...      2.213762   0.099239
# 13  0.331837   4.226830   3.044673   2.328830   ...      3.045738   0.145948
# 14  0.343089   4.226830   3.044673   2.330768   ...      1.391278   0.200955
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.351434   0.325546   0.157124   0.174009   0.351865     1.75     2.25
# 1    0.388741   0.448774   0.447753   0.101946   1.043326     7.75     4.25
# 2    0.327689   0.900488   0.593221   0.196519   2.177824    11.00     6.25
# 3    0.528233   1.886654   1.212859   0.102933   1.763332    13.25     8.75
# 4    0.286848   3.092095   0.850860   0.240797   2.477782    16.75    10.75
# 5    0.207689   9.438187   1.096634   0.437714   2.214147    20.50    13.25
# 6    0.718030  34.246218   2.057028   1.568094   4.832478    22.00    18.25
# 7    0.751112  26.695083   1.940995   2.141683   2.774995    24.25    19.50
# 8    0.995376  42.381926   1.620786   1.687301   3.522642    26.00    22.75
# 9    0.537140  55.459670   1.833960   1.033861   8.451516    27.50    27.25
# 10   1.575825  19.243628   4.219212   1.356835   3.056375    29.00    29.00
# 11   4.252149  35.469399   9.432313   1.993502   5.159740    29.50    31.00
# 12   2.782134  10.806331  12.663444   5.463100   5.450583    30.75    33.50
# 13  18.227311   4.215095  22.428023   4.237124   3.832363    33.00    35.25
# 14  25.894487   4.536663  12.297033  38.157294   8.148447    34.00    37.00
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      6.75
# 3      8.75
# 4      9.00
# 5     11.00
# 6     12.75
# 7     15.50
# 8     19.00
# 9     21.25
# 10    24.00
# 11    25.25
# 12    26.75
# 13    28.25
# 14    29.50
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'LowMarket'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:16:55  INFO: started running
# time: Thu 2017-01-26 21:16:59  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:17:19  INFO: started running
# time: Thu 2017-01-26 21:17:22  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:17:42  INFO: started running
# time: Thu 2017-01-26 21:17:45  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:18:01  INFO: started running
# time: Thu 2017-01-26 21:18:04  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.163817  0.161806
# 1         10.75            18.00    2.953682  3.058152  0.168329  0.167101
# 2          9.00            27.00    2.901060  2.955005  0.177514  0.173833
# 3          8.50            35.50    2.675768  2.713125  0.207401  0.188860
# 4          8.50            44.00    2.589692  2.602495  0.184486  0.189872
# 5          6.50            50.50    2.560952  2.569830  0.216493  0.189872
# 6         13.00            63.50    2.616405  2.644348  0.216493  0.197027
# 7         10.00            73.50    2.688623  2.764407  0.254012  0.214161
# 8         10.00            83.50    2.576620  2.598632  0.263171  0.221052
# 9         12.25            95.75    2.641438  2.672983  0.269555  0.249923
# 10        10.50           106.25    2.540227  2.570432  0.276440  0.263848
# 11         7.50           113.75    2.486483  2.511135  0.244825  0.290837
# 12         8.75           122.50    2.597830  2.693022  0.288423  0.279837
# 13         9.50           132.00    2.483042  2.510092  0.281315  0.286016
# 14        10.25           142.25    2.518747  2.560025  0.286035  0.285760
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158270   0.117857   0.151805   0.169586   ...      0.096278   0.375584
# 1   0.163488   0.458995   0.187855   0.123721   ...      0.075683   0.285536
# 2   0.170715   0.523757   1.054353   0.154649   ...      0.137966   0.307993
# 3   0.224634   0.378149   1.049052   2.192388   ...      0.536189   0.231695
# 4   0.207771   0.241422   0.096931   1.350184   ...      2.484799   0.160077
# 5   0.220192   0.481549   0.096931   4.348060   ...      4.320552   0.099106
# 6   0.211759   0.481549   1.599778   4.349099   ...      8.356440   0.180517
# 7   0.211759   2.339183   3.356550   4.349099   ...      6.488206   0.096521
# 8   0.219969   0.235237   3.361189   0.160414   ...      2.497815   0.071970
# 9   0.229031  55.435919   0.875412   0.197045   ...      2.362501   0.062525
# 10  0.281358  55.444892   0.875127   1.751973   ...      7.038025   0.095487
# 11  0.280119  55.368732   7.822165  38.871141   ...      9.364359   0.099707
# 12  0.298572  57.455722   3.404309   1.229608   ...      2.213762   0.099239
# 13  0.308685  55.487485   3.448202   1.221003   ...      3.045738   0.145948
# 14  0.333601  55.525792   3.471025   1.246988   ...      1.391278   0.200955
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.351434   0.325546   0.157124   0.174009   0.351865     1.75     2.25
# 1    0.388741   0.448774   0.447753   0.101946   1.043326     7.50     5.00
# 2    0.327689   0.900488   0.593221   0.196519   2.177824    11.00     7.50
# 3    0.528233   1.886654   1.212859   0.102933   1.763332    13.25    11.75
# 4    0.286848   3.092095   0.850860   0.240797   2.477782    16.50    16.00
# 5    0.207689   9.438187   1.096634   0.437714   2.214147    18.50    17.75
# 6    0.718030  34.246218   2.057028   1.568094   4.832478    22.25    24.00
# 7    0.751112  26.695083   1.940995   2.141683   2.774995    25.50    26.25
# 8    0.995376  42.381926   1.620786   1.687301   3.522642    29.50    29.00
# 9    0.537140  55.459670   1.833960   1.033861   8.451516    33.50    32.25
# 10   1.575825  19.243628   4.219212   1.356835   3.056375    36.75    35.00
# 11   4.252149  35.469399   9.432313   1.993502   5.159740    38.50    39.50
# 12   2.782134  10.806331  12.663444   5.463100   5.450583    41.25    42.00
# 13  18.227311   4.215095  22.428023   4.237124   3.832363    45.25    44.25
# 14  25.894487   4.536663  12.297033  38.157294   8.148447    48.25    48.50
#
#     sei_N_2
# 0      3.25
# 1      5.50
# 2      8.50
# 3     10.50
# 4     11.50
# 5     14.25
# 6     17.25
# 7     21.75
# 8     25.00
# 9     30.00
# 10    34.50
# 11    35.75
# 12    39.25
# 13    42.50
# 14    45.50
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'HighSoftCosts'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:18:21  INFO: started running
# time: Thu 2017-01-26 21:18:24  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:18:41  INFO: started running
# time: Thu 2017-01-26 21:18:44  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:19:01  INFO: started running
# time: Thu 2017-01-26 21:19:05  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:19:25  INFO: started running
# time: Thu 2017-01-26 21:19:27  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          5.00             5.00    3.573878  3.606673  0.162242  0.165589
# 1          8.00            13.00    3.355685  3.604315  0.169149  0.166852
# 2          9.00            22.00    3.023675  3.041895  0.170588  0.165312
# 3          7.50            29.50    2.915955  2.968360  0.197816  0.172196
# 4          8.25            37.75    2.675263  2.704087  0.230585  0.193603
# 5         10.50            48.25    2.655632  2.690170  0.227574  0.215230
# 6         11.25            59.50    2.660423  2.720655  0.217700  0.241323
# 7          7.25            66.75    2.793213  2.892517  0.225963  0.241323
# 8          9.25            76.00    2.676950  2.778223  0.228603  0.242739
# 9          8.75            84.75    2.730805  2.890672  0.235104  0.242739
# 10         9.25            94.00    2.769793  2.882938  0.246314  0.245738
# 11         7.25           101.25    2.631933  2.658898  0.260186  0.242690
# 12         7.00           108.25    2.631325  2.774517  0.312804  0.265929
# 13         9.25           117.50    2.627422  2.673185  0.319335  0.265929
# 14         7.50           125.00    2.655353  2.741780  0.312796  0.257866
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.106894   0.303464   0.200000   ...      0.096278   0.375584
# 1   0.178903   0.056202   0.261180   0.375644   ...      0.075683   0.285536
# 2   0.180074   0.153634   0.221886   0.479919   ...      0.137966   0.307993
# 3   0.188980   0.305212   0.178151   0.510220   ...      0.536189   0.231695
# 4   0.199879   0.181695   0.424963   0.099819   ...      2.484799   0.160077
# 5   0.208118   0.971870   0.365885   0.154809   ...      4.320552   0.099106
# 6   0.227165   1.653509   0.362140   0.139288   ...      8.356440   0.180517
# 7   0.216635   1.814114   0.362140   0.356784   ...      6.488206   0.096521
# 8   0.248112  43.961636   0.458722   0.412599   ...      2.497815   0.071970
# 9   0.251595  44.002523   0.458722   0.367317   ...      2.362501   0.062525
# 10  0.259165   1.850847   0.277743   0.393719   ...      7.038025   0.095487
# 11  0.285974   2.054704   0.250044   1.000113   ...      9.364359   0.099707
# 12  0.274406   1.585711   1.204776   2.325028   ...      2.213762   0.099239
# 13  0.276677   0.125033   1.204776   2.327158   ...      3.045738   0.145948
# 14  0.276677   0.125790   3.155383   2.327158   ...      1.391278   0.200955
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.351434   0.325546   0.157124   0.174009   0.351865     1.00     1.50
# 1    0.388741   0.448774   0.447753   0.101946   1.043326     4.50     4.50
# 2    0.327689   0.900488   0.593221   0.196519   2.177824     8.25     7.25
# 3    0.528233   1.886654   1.212859   0.102933   1.763332    11.00    10.00
# 4    0.286848   3.092095   0.850860   0.240797   2.477782    14.50    13.00
# 5    0.207689   9.438187   1.096634   0.437714   2.214147    19.25    16.00
# 6    0.718030  34.246218   2.057028   1.568094   4.832478    23.50    20.75
# 7    0.751112  26.695083   1.940995   2.141683   2.774995    27.00    22.75
# 8    0.995376  42.381926   1.620786   1.687301   3.522642    30.50    25.50
# 9    0.537140  55.459670   1.833960   1.033861   8.451516    33.75    29.25
# 10   1.575825  19.243628   4.219212   1.356835   3.056375    37.25    31.00
# 11   4.252149  35.469399   9.432313   1.993502   5.159740    39.00    34.00
# 12   2.782134  10.806331  12.663444   5.463100   5.450583    42.00    35.75
# 13  18.227311   4.215095  22.428023   4.237124   3.832363    45.50    38.75
# 14  25.894487   4.536663  12.297033  38.157294   8.148447    47.50    41.75
#
#     sei_N_2
# 0      2.50
# 1      4.00
# 2      6.50
# 3      8.50
# 4     10.25
# 5     13.00
# 6     15.25
# 7     17.00
# 8     20.00
# 9     21.75
# 10    25.75
# 11    28.25
# 12    30.50
# 13    33.25
# 14    35.75
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'HighMaintenanceCosts'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:19:49  INFO: started running
# time: Thu 2017-01-26 21:19:53  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:20:10  INFO: started running
# time: Thu 2017-01-26 21:20:13  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:20:30  INFO: started running
# time: Thu 2017-01-26 21:20:33  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:20:50  INFO: started running
# time: Thu 2017-01-26 21:20:53  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
# Out:
#     N_installed  N_installed_sum  P_av_total      P_av     sei_0     sei_1  \
# 0          7.25             7.25    3.505335  3.507450  0.166072  0.163400
# 1          9.00            16.25    3.120900  3.239685  0.160878  0.166603
# 2          7.75            24.00    3.031885  3.081950  0.185325  0.183497
# 3          8.00            32.00    2.769887  2.804883  0.166447  0.183598
# 4          9.25            41.25    2.751590  2.754580  0.176968  0.208037
# 5          8.75            50.00    2.698115  2.700790  0.187782  0.215086
# 6         11.50            61.50    2.667810  2.748815  0.191784  0.234789
# 7          9.75            71.25    2.706365  2.779668  0.215202  0.227394
# 8         10.75            82.00    2.606122  2.635585  0.211379  0.228852
# 9         11.25            93.25    2.587322  2.629820  0.250564  0.265688
# 10        10.50           103.75    2.558755  2.586187  0.302367  0.265688
# 11         8.75           112.50    2.553198  2.656648  0.303131  0.255170
# 12        10.75           123.25    2.552975  2.633470  0.307193  0.298102
# 13         9.50           132.75    2.501410  2.521215  0.307315  0.298102
# 14        10.00           142.75    2.600328  2.638250  0.325650  0.354155
#
#        sei_2  sei_rel_0  sei_rel_1  sei_rel_2   ...     sem_rel_0  sem_rel_1  \
# 0   0.158250   0.111076   0.200000   0.200000   ...      0.096278   0.375584
# 1   0.164944   0.071670   0.161779   0.126028   ...      0.075683   0.285536
# 2   0.163266   0.176007   0.089685   0.249313   ...      0.137966   0.307993
# 3   0.171004   0.039946   0.083569   0.204110   ...      0.536189   0.231695
# 4   0.202703   0.023861   0.856347   0.217913   ...      2.484799   0.160077
# 5   0.236408   0.022541   0.547949   0.125838   ...      4.320552   0.099106
# 6   0.252813   0.028283   0.349383   0.054500   ...      8.356440   0.180517
# 7   0.239271   0.525345   0.628338   1.813775   ...      6.488206   0.096521
# 8   0.245268   0.296974   0.308978   0.197417   ...      2.497815   0.071970
# 9   0.248219  55.769128   8.549820   7.687227   ...      2.362501   0.062525
# 10  0.233043   0.569740   8.549820  26.168813   ...      7.038025   0.095487
# 11  0.271575   0.567699   9.625207  23.101605   ...      9.364359   0.099707
# 12  0.271575  13.563230   4.231644  23.101605   ...      2.213762   0.099239
# 13  0.295396   6.954304   4.231644  22.944313   ...      3.045738   0.145948
# 14  0.296783   9.996070   3.551922  22.934426   ...      1.391278   0.200955
#
#     sem_rel_2  sem_rel_3  sem_rel_4  sem_rel_5  sem_rel_6  sei_N_0  sei_N_1  \
# 0    0.351434   0.325546   0.157124   0.174009   0.351865     1.75     2.25
# 1    0.388741   0.448774   0.447753   0.101946   1.043326     7.50     4.25
# 2    0.327689   0.900488   0.593221   0.196519   2.177824    10.75     6.25
# 3    0.528233   1.886654   1.212859   0.102933   1.763332    13.00     9.75
# 4    0.286848   3.092095   0.850860   0.240797   2.477782    17.75    13.00
# 5    0.207689   9.438187   1.096634   0.437714   2.214147    21.75    15.75
# 6    0.718030  34.246218   2.057028   1.568094   4.832478    26.25    21.25
# 7    0.751112  26.695083   1.940995   2.141683   2.774995    29.50    24.25
# 8    0.995376  42.381926   1.620786   1.687301   3.522642    33.50    27.50
# 9    0.537140  55.459670   1.833960   1.033861   8.451516    36.50    30.75
# 10   1.575825  19.243628   4.219212   1.356835   3.056375    40.00    34.25
# 11   4.252149  35.469399   9.432313   1.993502   5.159740    42.00    38.50
# 12   2.782134  10.806331  12.663444   5.463100   5.450583    44.50    42.50
# 13  18.227311   4.215095  22.428023   4.237124   3.832363    47.00    45.00
# 14  25.894487   4.536663  12.297033  38.157294   8.148447    50.25    48.75
#
#     sei_N_2
# 0      3.25
# 1      4.50
# 2      7.00
# 3      9.25
# 4     10.50
# 5     12.50
# 6     14.00
# 7     17.50
# 8     21.00
# 9     26.00
# 10    29.50
# 11    32.00
# 12    36.25
# 13    40.75
# 14    43.75
#
# [15 rows x 27 columns]

# %%
#read setup file and change seed
test_mode = 'HighReturnsH'
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# Out:
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:21:11  INFO: started running
# time: Thu 2017-01-26 21:21:17  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
# time: Thu 2017-01-26 21:21:36  INFO: started running
# time: Thu 2017-01-26 21:21:41  INFO: stopped running
# /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model
# /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]

# %%
#read setup file and change seed
test_mode = ''
data_mode = 'MA'
file = '/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/' + test_mode + '/' + data_mode + '/w.json'


mode="NEW"
model_file="/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Examples/EEModel/" + test_mode + '/' + data_mode + "/eemodel.model"
    
with open(file) as infile:
    w_setup = json.load(infile)
    
for seed in (2016, 2015, 2014, 2012):
    w_setup['SEED'] = seed
    with open(file, 'w') as outfile:
        json.dump(w_setup, outfile)
        
    #run simulation 
    # %cd /Users/wilfeli/Library/Developer/Xcode/DerivedData/ABMSolar-gkzppcalpbhpwocspomkmqhbbhyr/Build/Products/Debug
    # !./SolarEE $mode $model_file
    # %cd /Users/wilfeli/Dropbox/ABM/SolarPanels/solar-model/Model

# %%
#names of columns in a file
names = ['N_installed', 'N_installed_sum', 'P_av_total', 'P_av']
for i in range(3):
    names.append('sei_' + str(i))
for i in range(3):
    names.append('sei_rel_' + str(i))
for i in range(7):
    names.append('sem_' + str(i))
for i in range(7):
    names.append('sem_rel_' + str(i))
for i in range(3):
    names.append('sei_N_' + str(i))


#read few files
#save into database
dfs_ = []
#read last simulation result
files = glob.glob('/Users/wilfeli/Dropbox/ABM/SolarPanels/ABMIRISLab/Saves/EEModel' + '/*[_w].csv')
files.sort(key=os.path.getmtime, reverse=True)

#take top 4 files 
for file in files[0:4]:
    df_ = pd.read_csv(file, names=names, low_memory=False)
    dfs_.append(df_)

#create df from them    
df_concat = pd.concat(dfs_)
df = df_concat.groupby(level=0).mean()
df_std = df_concat.groupby(level=0).std()

#alternative way to calculate means
by_row_index = df_concat.groupby(df_concat.index)
df_means = by_row_index.mean()
df_means.head()
df_means[:15]
